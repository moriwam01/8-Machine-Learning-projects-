# %%
import warnings
warning.filterwarning('ignore')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1302d87615ad> in <module>
#       1 import warnings
# ----> 2 warning.filterwarning('ignore')
#
# NameError: name 'warning' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import math
import shutil
import glob

# %%
ROOT_DIR = ""
